# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('Alcohol_Sales.csv')

# %%
df
# Out:
#            DATE  S4248SM144NCEN
# 0    1992-01-01            3459
# 1    1992-02-01            3458
# 2    1992-03-01            4002
# 3    1992-04-01            4564
# 4    1992-05-01            4221
# ..          ...             ...
# 320  2018-09-01           12396
# 321  2018-10-01           13914
# 322  2018-11-01           14174
# 323  2018-12-01           15504
# 324  2019-01-01           10718
#
# [325 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['DATE', 'S4248SM144NCEN'], dtype='object')

# %%
df.columns=['DATE','Sales']
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            DATE  Sales
# 0    1992-01-01   3459
# 1    1992-02-01   3458
# 2    1992-03-01   4002
# 3    1992-04-01   4564
# 4    1992-05-01   4221
# ..          ...    ...
# 320  2018-09-01  12396
# 321  2018-10-01  13914
# 322  2018-11-01  14174
# 323  2018-12-01  15504
# 324  2019-01-01  10718
#
# [325 rows x 2 columns]

# %%
df['Sale_LastMonth']=df['Sales'].shift(+1)

# %%
df['Sale_2Monthsback']=df['Sales'].shift(+2)

# %%
df['Sale_3Monthback']=df['Sales'].shift(+3)

# %%
df
# Out:
#            DATE  Sales  Sale_LastMonth  Sale_2Monthsback  Sale_3Monthback
# 0    1992-01-01   3459             NaN               NaN              NaN
# 1    1992-02-01   3458          3459.0               NaN              NaN
# 2    1992-03-01   4002          3458.0            3459.0              NaN
# 3    1992-04-01   4564          4002.0            3458.0           3459.0
# 4    1992-05-01   4221          4564.0            4002.0           3458.0
# ..          ...    ...             ...               ...              ...
# 320  2018-09-01  12396         14257.0           12640.0          14583.0
# 321  2018-10-01  13914         12396.0           14257.0          12640.0
# 322  2018-11-01  14174         13914.0           12396.0          14257.0
# 323  2018-12-01  15504         14174.0           13914.0          12396.0
# 324  2019-01-01  10718         15504.0           14174.0          13914.0
#
# [325 rows x 5 columns]

# %%
df=df.dropna()
df
# Out:
#            DATE  Sales  Sale_LastMonth  Sale_2Monthsback  Sale_3Monthback
# 3    1992-04-01   4564          4002.0            3458.0           3459.0
# 4    1992-05-01   4221          4564.0            4002.0           3458.0
# 5    1992-06-01   4529          4221.0            4564.0           4002.0
# 6    1992-07-01   4466          4529.0            4221.0           4564.0
# 7    1992-08-01   4137          4466.0            4529.0           4221.0
# ..          ...    ...             ...               ...              ...
# 320  2018-09-01  12396         14257.0           12640.0          14583.0
# 321  2018-10-01  13914         12396.0           14257.0          12640.0
# 322  2018-11-01  14174         13914.0           12396.0          14257.0
# 323  2018-12-01  15504         14174.0           13914.0          12396.0
# 324  2019-01-01  10718         15504.0           14174.0          13914.0
#
# [322 rows x 5 columns]

# %%
x=df.iloc[:,2:]

# %%
x
# Out:
#      Sale_LastMonth  Sale_2Monthsback  Sale_3Monthback
# 3            4002.0            3458.0           3459.0
# 4            4564.0            4002.0           3458.0
# 5            4221.0            4564.0           4002.0
# 6            4529.0            4221.0           4564.0
# 7            4466.0            4529.0           4221.0
# ..              ...               ...              ...
# 320         14257.0           12640.0          14583.0
# 321         12396.0           14257.0          12640.0
# 322         13914.0           12396.0          14257.0
# 323         14174.0           13914.0          12396.0
# 324         15504.0           14174.0          13914.0
#
# [322 rows x 3 columns]

# %%
y=df.iloc[:,1:2]

# %%
y
# Out:
#      Sales
# 3     4564
# 4     4221
# 5     4529
# 6     4466
# 7     4137
# ..     ...
# 320  12396
# 321  13914
# 322  14174
# 323  15504
# 324  10718
#
# [322 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.fit_transform(xtest)
ytrain=scaler.fit_transform(ytrain)
ytest=scaler.fit_transform(ytest)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# Step 5: Build and train the MLP model
model = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model.fit(xtrain,ytrain,epochs=100,batch_size=5)
# Out:
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 0.0787 - mean_absolute_error: 0.2083
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0093 - mean_absolute_error: 0.0734
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0085 - mean_absolute_error: 0.0678
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0069 - mean_absolute_error: 0.0606
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.0081 - mean_absolute_error: 0.0667
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0078 - mean_absolute_error: 0.0620
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0071 - mean_absolute_error: 0.0607
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0106 - mean_absolute_error: 0.0796
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0071 - mean_absolute_error: 0.0615
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0081 - mean_absolute_error: 0.0624
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0083 - mean_absolute_error: 0.0644
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0057 - mean_absolute_error: 0.0525
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0077 - mean_absolute_error: 0.0620
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - mean_absolute_error: 0.0603
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0078 - mean_absolute_error: 0.0636
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0084 - mean_absolute_error: 0.0624
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0073 - mean_absolute_error: 0.0586
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0078 - mean_absolute_error: 0.0640
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0072 - mean_absolute_error: 0.0583
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0071 - mean_absolute_error: 0.0601
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.0057 - mean_absolute_error: 0.0526
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0093 - mean_absolute_error: 0.0680
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0090 - mean_absolute_error: 0.0648
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0078 - mean_absolute_error: 0.0635
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.0071 - mean_absolute_error: 0.0630
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0116 - mean_absolute_error: 0.0791
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0066 - mean_absolute_error: 0.0555
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0066 - mean_absolute_error: 0.0570
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0068 - mean_absolute_error: 0.0601
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0082 - mean_absolute_error: 0.0646
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0077 - mean_absolute_error: 0.0663
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0063 - mean_absolute_error: 0.0565
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0082 - mean_absolute_error: 0.0658
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0086 - mean_absolute_error: 0.0627
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0083 - mean_absolute_error: 0.0637
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0077 - mean_absolute_error: 0.0607
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.0068 - mean_absolute_error: 0.0581
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0061 - mean_absolute_error: 0.0555
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0068 - mean_absolute_error: 0.0601
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0070 - mean_absolute_error: 0.0576
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0627
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0070 - mean_absolute_error: 0.0590
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0065 - mean_absolute_error: 0.0568
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0066 - mean_absolute_error: 0.0573
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0058 - mean_absolute_error: 0.0493
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0063 - mean_absolute_error: 0.0548
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0073 - mean_absolute_error: 0.0601
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0082 - mean_absolute_error: 0.0653
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0074 - mean_absolute_error: 0.0590
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0069 - mean_absolute_error: 0.0574
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.0062 - mean_absolute_error: 0.0542
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0061 - mean_absolute_error: 0.0545
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0076 - mean_absolute_error: 0.0577
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0074 - mean_absolute_error: 0.0642
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0086 - mean_absolute_error: 0.0670
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0062 - mean_absolute_error: 0.0532
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0071 - mean_absolute_error: 0.0592
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0068 - mean_absolute_error: 0.0578
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0075 - mean_absolute_error: 0.0589
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0080 - mean_absolute_error: 0.0635
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0076 - mean_absolute_error: 0.0630
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0066 - mean_absolute_error: 0.0561
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0100 - mean_absolute_error: 0.0690
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 0.0061 - mean_absolute_error: 0.0550
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0069 - mean_absolute_error: 0.0584
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0071 - mean_absolute_error: 0.0600
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0081 - mean_absolute_error: 0.0652
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0065 - mean_absolute_error: 0.0561
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.0077 - mean_absolute_error: 0.0625
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.0067 - mean_absolute_error: 0.0572
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0639
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.0060 - mean_absolute_error: 0.0550
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0073 - mean_absolute_error: 0.0598
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0062 - mean_absolute_error: 0.0576
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0067 - mean_absolute_error: 0.0614
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0653
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0066 - mean_absolute_error: 0.0594
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0062 - mean_absolute_error: 0.0548
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0083 - mean_absolute_error: 0.0646
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0073 - mean_absolute_error: 0.0601
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.0056 - mean_absolute_error: 0.0527
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0060 - mean_absolute_error: 0.0541
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 0.0077 - mean_absolute_error: 0.0647
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.0070 - mean_absolute_error: 0.0597
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.0073 - mean_absolute_error: 0.0586
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0078 - mean_absolute_error: 0.0597
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0076 - mean_absolute_error: 0.0591
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0064 - mean_absolute_error: 0.0553
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0073 - mean_absolute_error: 0.0605
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0048 - mean_absolute_error: 0.0459
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0079 - mean_absolute_error: 0.0609
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0076 - mean_absolute_error: 0.0629
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0066 - mean_absolute_error: 0.0587
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0067 - mean_absolute_error: 0.0594
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0073 - mean_absolute_error: 0.0597
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0060 - mean_absolute_error: 0.0571
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0062 - mean_absolute_error: 0.0554
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0054 - mean_absolute_error: 0.0511
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.0084 - mean_absolute_error: 0.0656
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0075 - mean_absolute_error: 0.0585

# %%
predict=model.predict(xtest)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
predict
# Out:
# array([[0.74160683],
#        [0.1418702 ],
#        [0.5189795 ],
#        [0.29349628],
#        [0.75012696],
#        [0.65339065],
#        [0.49001774],
#        [0.1290615 ],
#        [0.2707592 ],
#        [0.13936718],
#        [0.13068812],
#        [0.35259828],
#        [0.3369073 ],
#        [0.7706486 ],
#        [0.47386697],
#        [0.6352048 ],
#        [0.10979061],
#        [0.14375062],
#        [0.47283366],
#        [0.27789548],
#        [0.17452686],
#        [0.00309237],
#        [0.51847506],
#        [0.31853732],
#        [0.03599362],
#        [0.3416343 ],
#        [0.7635908 ],
#        [0.52330536],
#        [0.58705133],
#        [0.72485673],
#        [0.38169703],
#        [0.21514775],
#        [0.13902764],
#        [0.06198771],
#        [0.5580679 ],
#        [0.570022  ],
#        [0.77332866],
#        [0.08675292],
#        [0.7095727 ],
#        [0.6867467 ],
#        [0.28534037],
#        [0.40441355],
#        [0.12216726],
#        [0.078651  ],
#        [0.12251253],
#        [0.5438871 ],
#        [0.17618123],
#        [0.6703579 ],
#        [0.28932855],
#        [0.7089263 ],
#        [0.602823  ],
#        [0.13280314],
#        [0.43078026],
#        [0.31612206],
#        [0.80303043],
#        [0.5643877 ],
#        [0.4206216 ],
#        [0.2009814 ],
#        [0.5810875 ],
#        [0.7024118 ],
#        [0.8445611 ],
#        [0.79298335],
#        [0.64080846],
#        [0.68656135],
#        [0.0704942 ],
#        [0.30252564],
#        [0.6793461 ],
#        [0.31039175],
#        [0.55088437],
#        [0.69222736],
#        [0.52617645],
#        [0.0855128 ],
#        [0.09457119],
#        [0.13997562],
#        [0.11662933],
#        [0.68926084],
#        [0.09471399],
#        [0.66680604],
#        [0.18034469],
#        [0.38684252],
#        [0.0835122 ],
#        [0.48687837],
#        [0.3528105 ],
#        [0.62827337],
#        [0.645098  ],
#        [0.21780886],
#        [0.33878767],
#        [0.09802507],
#        [0.1992908 ],
#        [0.73073316],
#        [0.39616314],
#        [0.72016   ],
#        [0.1170415 ],
#        [0.14650819],
#        [0.08312994],
#        [0.44815958],
#        [0.21534517]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot(predict,label = 'Multi Layer Perceptrons')
plt.plot(ytest,label = 'Actual Sales')
plt.legend(loc= 'upper left')
plt.show()

# %%
def create_model():
    model = Sequential([
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1)  # Output layer for regression
    ])

    return model

# %%
from scikeras.wrappers import KerasRegressor

# %%
model = KerasRegressor(model=create_model, loss='mean_squared_error', epochs=100, batch_size=10, verbose=0)

# %%
from sklearn.model_selection import GridSearchCV

# %%
xtrain.dtype,ytrain.dtype
# Out:
# (dtype('float64'), dtype('float64'))

# %%
xtrain.shape,ytrain.shape
# Out:
# ((225, 3), (225, 1))

# %%
#Input(shape=(input_dim,)),  # Dynamically set the input shape

# %%
def create_model(optimizer='adam'):
    model = Sequential()
    model.add(Dense(12, input_dim=xtrain.shape[1], activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Ensure this matches your task (binary classification)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'

# %%
input_dim = xtrain.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense, Input

def create_model(xtrain, optimizer='adam'):
    input_dim = xtrain.shape[1]  # Number of features in the training data

    model = Sequential()
    model.add(Input(shape=(input_dim,)))  # Define the input shape
    model.add(Dense(12, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Ensure this matches your task (binary classification)

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense, Input

def create_model(input_dim, optimizer='adam'):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))  # Input shape
    model.add(Dense(12, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# Wrapping the Keras model using KerasClassifier
model = KerasRegressor(build_fn=create_model, input_dim=xtrain.shape[1], verbose=0)

# Define the grid search parameters
param_grid = {
    'optimizer' :['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam'],
    'batch_size': [5, 10],
    'epochs': [100, 200]
}

# Perform grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(xtrain, ytrain)

# Summarize the results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491867.955889  283489 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733491867.962336  283489 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491867.990723  283488 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491867.997029  283490 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733491867.997568  283488 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1733491868.003692  283490 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491868.069127  283491 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491868.071825  283492 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491868.074864  283493 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733491868.076889  283491 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1733491868.077812  283492 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1733491868.082063  283493 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491868.127911  283494 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733491868.134627  283494 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733491868.168269  283495 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733491868.174810  283495 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491870.765332  283489 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491870.881224  283490 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491870.899684  283488 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491871.041477  283495 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491871.117768  283494 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491871.198618  283493 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# W0000 00:00:1733491871.207317  283491 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# W0000 00:00:1733491871.250422  283492 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x722c7f551360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x76d973529360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e9262b71360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x722c7ff6e4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x76d973f464d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e926358a4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x789180d5d360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ec2b2b75360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x766250121360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x789181766b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ec2b3582b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x76625022eb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x75a6104da830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d453d7c6830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/suchi/.local/lib/python3.10/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x75a6106ea710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d453ebd6710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Best: 0.844768 using {'batch_size': 5, 'epochs': 200, 'optimizer': 'Adagrad'}
# 0.837544 (0.022226) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'SGD'}
# 0.836428 (0.013914) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'RMSprop'}
# 0.837678 (0.004859) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'Adagrad'}
# 0.838129 (0.019066) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'Adadelta'}
# 0.840473 (0.020865) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'Adam'}
# 0.834608 (0.021456) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'Adamax'}
# 0.835656 (0.017073) with: {'batch_size': 5, 'epochs': 100, 'optimizer': 'Nadam'}
# 0.843407 (0.005946) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'SGD'}
# 0.840149 (0.011781) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'RMSprop'}
# 0.844768 (0.010649) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'Adagrad'}
# 0.839552 (0.014879) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'Adadelta'}
# 0.844525 (0.010539) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'Adam'}
# 0.844011 (0.021754) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'Adamax'}
# 0.831298 (0.022700) with: {'batch_size': 5, 'epochs': 200, 'optimizer': 'Nadam'}
# 0.837711 (0.009502) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'SGD'}
# 0.836850 (0.020462) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'RMSprop'}
# 0.838589 (0.011685) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'Adagrad'}
# 0.838589 (0.015028) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'Adadelta'}
# 0.837040 (0.015651) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'Adam'}
# 0.821020 (0.005030) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'Adamax'}
# 0.826308 (0.023422) with: {'batch_size': 10, 'epochs': 100, 'optimizer': 'Nadam'}
# 0.832924 (0.014430) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'SGD'}
# 0.841342 (0.020046) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'RMSprop'}
# 0.842012 (0.015178) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'Adagrad'}
# 0.838472 (0.014629) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'Adadelta'}
# 0.844261 (0.018913) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'Adam'}
# 0.838062 (0.012972) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'Adamax'}
# 0.836011 (0.020792) with: {'batch_size': 10, 'epochs': 200, 'optimizer': 'Nadam'}

# %% [markdown]
# ### Now save this model

# %%
model = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

model.compile(optimizer='Adagrad', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.fit(xtrain,ytrain,epochs=200,batch_size=5)
# Out:
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3567 - mean_absolute_error: 0.5103
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2162 - mean_absolute_error: 0.3882
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1503 - mean_absolute_error: 0.3104
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1156 - mean_absolute_error: 0.2625
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1062 - mean_absolute_error: 0.2575
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0897 - mean_absolute_error: 0.2294
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0685 - mean_absolute_error: 0.1998
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0583 - mean_absolute_error: 0.1789
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0531 - mean_absolute_error: 0.1830
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0482 - mean_absolute_error: 0.1629
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0434 - mean_absolute_error: 0.1611
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0371 - mean_absolute_error: 0.1479
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0265 - mean_absolute_error: 0.1243
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0314 - mean_absolute_error: 0.1377
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0269 - mean_absolute_error: 0.1273
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0281 - mean_absolute_error: 0.1290
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - mean_absolute_error: 0.1110
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0234 - mean_absolute_error: 0.1207
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0195 - mean_absolute_error: 0.1094
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0198 - mean_absolute_error: 0.1110
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0176 - mean_absolute_error: 0.1091
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0161 - mean_absolute_error: 0.1032
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1096
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0985
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0149 - mean_absolute_error: 0.0987
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0155 - mean_absolute_error: 0.1041
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0160 - mean_absolute_error: 0.1010
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0140 - mean_absolute_error: 0.0952
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0967
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0995
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152 - mean_absolute_error: 0.0980
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0140 - mean_absolute_error: 0.0948
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0148 - mean_absolute_error: 0.1000
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0966
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0133 - mean_absolute_error: 0.0925
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0913
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0139 - mean_absolute_error: 0.0950
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0917
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - mean_absolute_error: 0.0929
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - mean_absolute_error: 0.0949
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - mean_absolute_error: 0.0958
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - mean_absolute_error: 0.0847
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0919
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - mean_absolute_error: 0.0965
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0887
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0879
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - mean_absolute_error: 0.0915
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0927
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - mean_absolute_error: 0.0905
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - mean_absolute_error: 0.0851
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0877
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0850
# Epoch 53/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - mean_absolute_error: 0.0850
# Epoch 54/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0888
# Epoch 55/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.0106 - mean_absolute_error: 0.0813
# Epoch 56/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - mean_absolute_error: 0.0823
# Epoch 57/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0132 - mean_absolute_error: 0.0928
# Epoch 58/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0089 - mean_absolute_error: 0.0746
# Epoch 59/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0095 - mean_absolute_error: 0.0752
# Epoch 60/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0117 - mean_absolute_error: 0.0845
# Epoch 61/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.0107 - mean_absolute_error: 0.0816
# Epoch 62/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0102 - mean_absolute_error: 0.0818
# Epoch 63/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.0118 - mean_absolute_error: 0.0874
# Epoch 64/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0102 - mean_absolute_error: 0.0797
# Epoch 65/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0782
# Epoch 66/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0107 - mean_absolute_error: 0.0825
# Epoch 67/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0093 - mean_absolute_error: 0.0757
# Epoch 68/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0112 - mean_absolute_error: 0.0844
# Epoch 69/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0116 - mean_absolute_error: 0.0839
# Epoch 70/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0094 - mean_absolute_error: 0.0760
# Epoch 71/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0098 - mean_absolute_error: 0.0775
# Epoch 72/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 0.0108 - mean_absolute_error: 0.0803
# Epoch 73/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0771
# Epoch 74/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - mean_absolute_error: 0.0790
# Epoch 75/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - mean_absolute_error: 0.0845
# Epoch 76/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0118 - mean_absolute_error: 0.0847
# Epoch 77/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0092 - mean_absolute_error: 0.0732
# Epoch 78/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0086 - mean_absolute_error: 0.0728
# Epoch 79/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0095 - mean_absolute_error: 0.0768
# Epoch 80/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0103 - mean_absolute_error: 0.0794
# Epoch 81/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0106 - mean_absolute_error: 0.0793
# Epoch 82/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0115 - mean_absolute_error: 0.0829
# Epoch 83/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0107 - mean_absolute_error: 0.0799
# Epoch 84/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - mean_absolute_error: 0.0831
# Epoch 85/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - mean_absolute_error: 0.0847
# Epoch 86/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - mean_absolute_error: 0.0841
# Epoch 87/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.0835
# Epoch 88/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0704
# Epoch 89/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - mean_absolute_error: 0.0783
# Epoch 90/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - mean_absolute_error: 0.0845
# Epoch 91/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - mean_absolute_error: 0.0729
# Epoch 92/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0095 - mean_absolute_error: 0.0745
# Epoch 93/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0707
# Epoch 94/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0704
# Epoch 95/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0750
# Epoch 96/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0701
# Epoch 97/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0087 - mean_absolute_error: 0.0702
# Epoch 98/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0101 - mean_absolute_error: 0.0762
# Epoch 99/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.0802
# Epoch 100/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0087 - mean_absolute_error: 0.0710
# Epoch 101/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - mean_absolute_error: 0.0832
# Epoch 102/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.0094 - mean_absolute_error: 0.0760
# Epoch 103/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0782
# Epoch 104/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0763
# Epoch 105/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0681
# Epoch 106/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0712
# Epoch 107/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0722
# Epoch 108/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0698
# Epoch 109/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0695
# Epoch 110/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - mean_absolute_error: 0.0840
# Epoch 111/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0743
# Epoch 112/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0647
# Epoch 113/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0091 - mean_absolute_error: 0.0738
# Epoch 114/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0666
# Epoch 115/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0713
# Epoch 116/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0703
# Epoch 117/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mean_absolute_error: 0.0732
# Epoch 118/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0103 - mean_absolute_error: 0.0748
# Epoch 119/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - mean_absolute_error: 0.0705
# Epoch 120/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0719
# Epoch 121/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0689
# Epoch 122/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mean_absolute_error: 0.0717
# Epoch 123/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0767
# Epoch 124/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0750
# Epoch 125/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - mean_absolute_error: 0.0772
# Epoch 126/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - mean_absolute_error: 0.0786
# Epoch 127/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - mean_absolute_error: 0.0713
# Epoch 128/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - mean_absolute_error: 0.0717
# Epoch 129/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0709
# Epoch 130/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0733
# Epoch 131/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - mean_absolute_error: 0.0682
# Epoch 132/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0073 - mean_absolute_error: 0.0660
# Epoch 133/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.0072 - mean_absolute_error: 0.0630
# Epoch 134/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - mean_absolute_error: 0.0783
# Epoch 135/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0667
# Epoch 136/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0618
# Epoch 137/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mean_absolute_error: 0.0707
# Epoch 138/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0680
# Epoch 139/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0673
# Epoch 140/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mean_absolute_error: 0.0713
# Epoch 141/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0087 - mean_absolute_error: 0.0701
# Epoch 142/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0664
# Epoch 143/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0664
# Epoch 144/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0695
# Epoch 145/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - mean_absolute_error: 0.0756
# Epoch 146/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0075 - mean_absolute_error: 0.0662
# Epoch 147/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0657
# Epoch 148/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - mean_absolute_error: 0.0768
# Epoch 149/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - mean_absolute_error: 0.0720
# Epoch 150/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0723
# Epoch 151/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085 - mean_absolute_error: 0.0681
# Epoch 152/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0683
# Epoch 153/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0710
# Epoch 154/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0677
# Epoch 155/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0700
# Epoch 156/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - mean_absolute_error: 0.0727
# Epoch 157/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085 - mean_absolute_error: 0.0702
# Epoch 158/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - mean_absolute_error: 0.0733
# Epoch 159/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0720
# Epoch 160/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0724
# Epoch 161/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - mean_absolute_error: 0.0717
# Epoch 162/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0627
# Epoch 163/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - mean_absolute_error: 0.0683
# Epoch 164/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0606
# Epoch 165/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - mean_absolute_error: 0.0695
# Epoch 166/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0743
# Epoch 167/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - mean_absolute_error: 0.0676
# Epoch 168/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0692
# Epoch 169/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0724
# Epoch 170/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0714
# Epoch 171/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0601
# Epoch 172/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mean_absolute_error: 0.0708
# Epoch 173/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.0075 - mean_absolute_error: 0.0656
# Epoch 174/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0690
# Epoch 175/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0676
# Epoch 176/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0645
# Epoch 177/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - mean_absolute_error: 0.0742
# Epoch 178/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0659
# Epoch 179/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - mean_absolute_error: 0.0668
# Epoch 180/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0705
# Epoch 181/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0071 - mean_absolute_error: 0.0607
# Epoch 182/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0714
# Epoch 183/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0661
# Epoch 184/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0640
# Epoch 185/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0664
# Epoch 186/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0648
# Epoch 187/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - mean_absolute_error: 0.0674
# Epoch 188/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0614
# Epoch 189/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0656
# Epoch 190/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0648
# Epoch 191/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0670
# Epoch 192/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0663
# Epoch 193/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0676
# Epoch 194/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0080 - mean_absolute_error: 0.0649
# Epoch 195/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0635
# Epoch 196/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.0719
# Epoch 197/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0614
# Epoch 198/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0648
# Epoch 199/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0633
# Epoch 200/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0649

# %%
import joblib
filename = 'timeSeries.sav'
joblib.dump(model,filename)
# Out:
# ['timeSeries.sav']

# %%
loadedModel = joblib.load('timeSeries.sav')

# %%
loadedModel.predict(xtest)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# array([[0.76422447],
#        [0.18949126],
#        [0.47171864],
#        [0.30163014],
#        [0.7076768 ],
#        [0.6351141 ],
#        [0.49117005],
#        [0.17607085],
#        [0.255351  ],
#        [0.17834698],
#        [0.15106142],
#        [0.3495503 ],
#        [0.35658735],
#        [0.7909857 ],
#        [0.44594222],
#        [0.691971  ],
#        [0.13861327],
#        [0.17867966],
#        [0.49765927],
#        [0.29984277],
#        [0.20104395],
#        [0.1048437 ],
#        [0.5161344 ],
#        [0.4232752 ],
#        [0.12383059],
#        [0.3192159 ],
#        [0.8109671 ],
#        [0.5669694 ],
#        [0.58613473],
#        [0.6998853 ],
#        [0.40194154],
#        [0.23784247],
#        [0.18591897],
#        [0.06026421],
#        [0.61391914],
#        [0.543293  ],
#        [0.70983166],
#        [0.11450085],
#        [0.6791878 ],
#        [0.6906766 ],
#        [0.27800786],
#        [0.44035518],
#        [0.14352508],
#        [0.09310988],
#        [0.16545601],
#        [0.5609674 ],
#        [0.2147788 ],
#        [0.6767485 ],
#        [0.30959767],
#        [0.6676066 ],
#        [0.6296276 ],
#        [0.141319  ],
#        [0.48534918],
#        [0.29477206],
#        [0.78762144],
#        [0.53054005],
#        [0.43156314],
#        [0.25194168],
#        [0.57440126],
#        [0.65670705],
#        [0.780669  ],
#        [0.7158344 ],
#        [0.7064596 ],
#        [0.6308368 ],
#        [0.07635366],
#        [0.33582473],
#        [0.64506835],
#        [0.32406354],
#        [0.6045046 ],
#        [0.72484314],
#        [0.5238245 ],
#        [0.11991927],
#        [0.12916411],
#        [0.16427752],
#        [0.14198194],
#        [0.6904407 ],
#        [0.12949015],
#        [0.62226844],
#        [0.26214388],
#        [0.44922823],
#        [0.10108183],
#        [0.53865045],
#        [0.38105378],
#        [0.64719033],
#        [0.69077694],
#        [0.22679843],
#        [0.35697138],
#        [0.11845963],
#        [0.27487102],
#        [0.74328643],
#        [0.44334382],
#        [0.6954011 ],
#        [0.14106119],
#        [0.15215297],
#        [0.11310408],
#        [0.45457304],
#        [0.2505302 ]], dtype=float32)
