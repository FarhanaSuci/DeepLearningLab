# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, Dropout

# Load the data
df = pd.read_csv('Alcohol_Sales.csv')  # Update with the correct file path

# Debug: Print column names to identify the sales column
print("Original columns:", df.columns)

# Adjust column names based on actual dataset
df.columns = ['DATE', 'Sales']  # Adjust if necessary

# Debug: Verify the updated DataFrame
print(df.head())

# Plot the sales data
df['DATE'] = pd.to_datetime(df['DATE'])

# Plot the data
plt.figure(figsize=(12, 8))  # Create a new figure
plt.plot(df['Sales'], label='Sales')
plt.title('Sales Over Time')
plt.ylabel('Sales')
plt.show()

# Create lag features for past months
df['Sale_LastMonth'] = df['Sales'].shift(+1)
df['Sale_2Monthsback'] = df['Sales'].shift(+2)
df['Sale_3Monthback'] = df['Sales'].shift(+3)

# Drop rows with missing values (due to shifting)
df = df.dropna()

# Prepare input (X) and output (y)
x = df.iloc[:, 2:].values  # Lag features
y = df.iloc[:, 1:2].values  # Current sales

# Split the data into train and test sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=42)

# Normalize the data
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

xtrain = scaler_x.fit_transform(xtrain)
xtest = scaler_x.transform(xtest)
ytrain = scaler_y.fit_transform(ytrain)
ytest = scaler_y.transform(ytest)

# Reshape input for CNN (samples, time steps, features)
xtrain = xtrain.reshape((xtrain.shape[0], xtrain.shape[1], 1))
xtest = xtest.reshape((xtest.shape[0], xtest.shape[1], 1))

# Build the CNN model
model = Sequential([
    Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(xtrain.shape[1], 1)),
    Dropout(0.2),  # Dropout for regularization
    Conv1D(filters=32, kernel_size=2, activation='relu'),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Train the model
history = model.fit(xtrain, ytrain, epochs=100, batch_size=5, validation_data=(xtest, ytest))

# Save the loss and validation loss to a CSV file
loss_data = pd.DataFrame({
    'Epoch': range(1, len(history.history['loss']) + 1),
    'Loss': history.history['loss'],
    'Validation Loss': history.history['val_loss']
})
loss_data.to_csv('training_loss.csv', index=False)

# Evaluate the model
loss, mae = model.evaluate(xtest, ytest)
print(f"Test Loss: {loss}, Test MAE: {mae}")

# Predict and plot
predict = model.predict(xtest)
plt.figure(figsize=(12, 8))
plt.plot(predict, label='Convolutional Neural Networks')
plt.plot(ytest, label='Actual Sales')
plt.legend(loc='upper left')
plt.show()
# Out:
# 2025-01-07 10:35:18.203655: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-07 10:35:18.392400: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Original columns: Index(['DATE', 'S4248SM144NCEN'], dtype='object')
#          DATE  Sales
# 0  1992-01-01   3459
# 1  1992-02-01   3458
# 2  1992-03-01   4002
# 3  1992-04-01   4564
# 4  1992-05-01   4221
# Epoch 1/100
# /home/suchi/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1267 - mean_absolute_error: 0.2685 - val_loss: 0.0134 - val_mean_absolute_error: 0.0928
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.0914 - val_loss: 0.0104 - val_mean_absolute_error: 0.0772
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0800 - val_loss: 0.0074 - val_mean_absolute_error: 0.0635
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0928 - val_loss: 0.0069 - val_mean_absolute_error: 0.0615
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0747 - val_loss: 0.0090 - val_mean_absolute_error: 0.0716
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0709 - val_loss: 0.0068 - val_mean_absolute_error: 0.0616
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0801 - val_loss: 0.0084 - val_mean_absolute_error: 0.0673
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0830 - val_loss: 0.0076 - val_mean_absolute_error: 0.0636
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0770 - val_loss: 0.0064 - val_mean_absolute_error: 0.0590
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0854 - val_loss: 0.0075 - val_mean_absolute_error: 0.0648
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0872 - val_loss: 0.0062 - val_mean_absolute_error: 0.0576
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - mean_absolute_error: 0.0790 - val_loss: 0.0061 - val_mean_absolute_error: 0.0570
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.0734 - val_loss: 0.0065 - val_mean_absolute_error: 0.0582
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0647 - val_loss: 0.0066 - val_mean_absolute_error: 0.0588
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0106 - mean_absolute_error: 0.0774 - val_loss: 0.0059 - val_mean_absolute_error: 0.0559
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.0741 - val_loss: 0.0059 - val_mean_absolute_error: 0.0563
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0711 - val_loss: 0.0063 - val_mean_absolute_error: 0.0569
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - mean_absolute_error: 0.0729 - val_loss: 0.0057 - val_mean_absolute_error: 0.0552
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - mean_absolute_error: 0.0797 - val_loss: 0.0060 - val_mean_absolute_error: 0.0556
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0645 - val_loss: 0.0058 - val_mean_absolute_error: 0.0552
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - mean_absolute_error: 0.0774 - val_loss: 0.0058 - val_mean_absolute_error: 0.0541
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - mean_absolute_error: 0.0810 - val_loss: 0.0068 - val_mean_absolute_error: 0.0607
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0805 - val_loss: 0.0057 - val_mean_absolute_error: 0.0551
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0653 - val_loss: 0.0078 - val_mean_absolute_error: 0.0629
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - mean_absolute_error: 0.0798 - val_loss: 0.0068 - val_mean_absolute_error: 0.0596
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0636 - val_loss: 0.0109 - val_mean_absolute_error: 0.0766
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0794 - val_loss: 0.0056 - val_mean_absolute_error: 0.0524
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0669 - val_loss: 0.0058 - val_mean_absolute_error: 0.0555
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0787 - val_loss: 0.0065 - val_mean_absolute_error: 0.0573
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0689 - val_loss: 0.0059 - val_mean_absolute_error: 0.0545
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0637 - val_loss: 0.0057 - val_mean_absolute_error: 0.0534
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0658 - val_loss: 0.0056 - val_mean_absolute_error: 0.0537
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0686 - val_loss: 0.0069 - val_mean_absolute_error: 0.0594
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0654 - val_loss: 0.0064 - val_mean_absolute_error: 0.0571
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0664 - val_loss: 0.0064 - val_mean_absolute_error: 0.0576
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.0658 - val_loss: 0.0058 - val_mean_absolute_error: 0.0543
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0683 - val_loss: 0.0058 - val_mean_absolute_error: 0.0542
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0663 - val_loss: 0.0060 - val_mean_absolute_error: 0.0540
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0691 - val_loss: 0.0062 - val_mean_absolute_error: 0.0566
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0681 - val_loss: 0.0056 - val_mean_absolute_error: 0.0531
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0677 - val_loss: 0.0057 - val_mean_absolute_error: 0.0528
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0632 - val_loss: 0.0064 - val_mean_absolute_error: 0.0571
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0652 - val_loss: 0.0057 - val_mean_absolute_error: 0.0534
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0658 - val_loss: 0.0060 - val_mean_absolute_error: 0.0544
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0685 - val_loss: 0.0056 - val_mean_absolute_error: 0.0529
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0667 - val_loss: 0.0059 - val_mean_absolute_error: 0.0529
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - mean_absolute_error: 0.0696 - val_loss: 0.0059 - val_mean_absolute_error: 0.0535
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0742 - val_loss: 0.0061 - val_mean_absolute_error: 0.0543
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0630 - val_loss: 0.0058 - val_mean_absolute_error: 0.0525
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0709 - val_loss: 0.0062 - val_mean_absolute_error: 0.0554
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.0688 - val_loss: 0.0056 - val_mean_absolute_error: 0.0530
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0625 - val_loss: 0.0063 - val_mean_absolute_error: 0.0562
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.0725 - val_loss: 0.0063 - val_mean_absolute_error: 0.0568
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0647 - val_loss: 0.0056 - val_mean_absolute_error: 0.0533
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0639 - val_loss: 0.0058 - val_mean_absolute_error: 0.0530
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0655 - val_loss: 0.0063 - val_mean_absolute_error: 0.0566
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0651 - val_loss: 0.0060 - val_mean_absolute_error: 0.0548
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0680 - val_loss: 0.0059 - val_mean_absolute_error: 0.0541
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.0708 - val_loss: 0.0055 - val_mean_absolute_error: 0.0533
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0638 - val_loss: 0.0057 - val_mean_absolute_error: 0.0532
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0620 - val_loss: 0.0058 - val_mean_absolute_error: 0.0525
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0605 - val_loss: 0.0056 - val_mean_absolute_error: 0.0521
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0671 - val_loss: 0.0060 - val_mean_absolute_error: 0.0534
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0671 - val_loss: 0.0057 - val_mean_absolute_error: 0.0525
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0665 - val_loss: 0.0067 - val_mean_absolute_error: 0.0571
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0675 - val_loss: 0.0059 - val_mean_absolute_error: 0.0545
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0558 - val_loss: 0.0058 - val_mean_absolute_error: 0.0526
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0634 - val_loss: 0.0058 - val_mean_absolute_error: 0.0539
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0757 - val_loss: 0.0056 - val_mean_absolute_error: 0.0527
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0686 - val_loss: 0.0058 - val_mean_absolute_error: 0.0537
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0650 - val_loss: 0.0075 - val_mean_absolute_error: 0.0601
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0751 - val_loss: 0.0057 - val_mean_absolute_error: 0.0529
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0649 - val_loss: 0.0057 - val_mean_absolute_error: 0.0522
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0622 - val_loss: 0.0062 - val_mean_absolute_error: 0.0547
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0570 - val_loss: 0.0059 - val_mean_absolute_error: 0.0533
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0627 - val_loss: 0.0069 - val_mean_absolute_error: 0.0572
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0722 - val_loss: 0.0062 - val_mean_absolute_error: 0.0566
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0688 - val_loss: 0.0056 - val_mean_absolute_error: 0.0531
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.0714 - val_loss: 0.0062 - val_mean_absolute_error: 0.0571
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0613 - val_loss: 0.0061 - val_mean_absolute_error: 0.0528
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0689 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - mean_absolute_error: 0.0704 - val_loss: 0.0058 - val_mean_absolute_error: 0.0522
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0606 - val_loss: 0.0061 - val_mean_absolute_error: 0.0546
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0688 - val_loss: 0.0058 - val_mean_absolute_error: 0.0528
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0576 - val_loss: 0.0063 - val_mean_absolute_error: 0.0541
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0662 - val_loss: 0.0062 - val_mean_absolute_error: 0.0547
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0661 - val_loss: 0.0062 - val_mean_absolute_error: 0.0556
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0649 - val_loss: 0.0068 - val_mean_absolute_error: 0.0591
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0635 - val_loss: 0.0059 - val_mean_absolute_error: 0.0547
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0612 - val_loss: 0.0060 - val_mean_absolute_error: 0.0535
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0713 - val_loss: 0.0061 - val_mean_absolute_error: 0.0552
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0624 - val_loss: 0.0056 - val_mean_absolute_error: 0.0522
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0702 - val_loss: 0.0059 - val_mean_absolute_error: 0.0536
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0564 - val_loss: 0.0067 - val_mean_absolute_error: 0.0565
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0638 - val_loss: 0.0060 - val_mean_absolute_error: 0.0534
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0655 - val_loss: 0.0060 - val_mean_absolute_error: 0.0534
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0616 - val_loss: 0.0062 - val_mean_absolute_error: 0.0550
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0635 - val_loss: 0.0067 - val_mean_absolute_error: 0.0586
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - mean_absolute_error: 0.0584 - val_loss: 0.0066 - val_mean_absolute_error: 0.0568
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0646 - val_loss: 0.0060 - val_mean_absolute_error: 0.0546
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0546
# Test Loss: 0.006015143357217312, Test MAE: 0.05459039658308029
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
